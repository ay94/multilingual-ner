# %%
# !pip install git+ssh://git@github.com-casm:CASM-Consulting/multilingual-evaluation.git

# %%
from pathlib import Path
from ner.dataset_base import TextFileDirDataset

# %%
class NewDataset(TextFileDirDataset):
    dataset_name = "NEW_DATASET"
    path = Path(__file__).resolve().parent / "data" / "MY_NEW_DATASET_NER_corpus-1.0"
    label_map = {
        # 'B-PER': 'B-PERS', 'I-PER': 'I-PERS',
        'B-MISC':'B-MISC', 'I-MISC':'I-MISC',
        'B-MIS0':'B-MISC', 'I-MIS0':'I-MISC',
        'B-MIS1':'B-MISC', 'I-MIS1':'I-MISC',
        'B-MIS2':'B-MISC', 'I-MIS2':'I-MISC',
        'B-MIS3':'B-MISC', 'I-MIS3':'I-MISC',
        'B-LOC':'B-LOC', 'I-LOC':'I-LOC',
        'B-ORG':'B-ORG', 'I-ORG':'I-ORG',
        'B-MIS':'B-MISC', 'I-MIS':'I-MISC',
        'B-MIS-1':'B-MISC',
        'B-MIS-2':'B-MISC',
        'B-MISS1':'B-MISC',
        'B-MIS1`':'B-MISC',
        'B-ENGLISH':'O',
        'B-SPANISH':'O',
        'I--ORG':'I-ORG',
        'O':'O',
        'IO':'O',
        'OO':'O'
    }

dataset = AQMAR()

# %%
model = CAMeL()

# %%
report = model.evaluate(dataset, type=Types.seqeval)
